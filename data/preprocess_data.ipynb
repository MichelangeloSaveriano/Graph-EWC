# %%
import glob
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt
import dask.dataframe as dd
import pickle
from dask.distributed import Client
client = Client(processes=False)
client
# Out:
# <Client: 'inproc://192.168.1.2/20780/1' processes=1 threads=12, memory=15.37 GiB>

# %%
f = 25 # Hz
E = 500 # Number of directed edges kept

# %%
print(f'Number of Files: {len(glob.glob("./SplitRead/*.csv"))}')
# Out:
# Number of Files: 536

# %%
df = dd.read_csv("./SplitRead/*.csv", parse_dates=['time']).repartition(npartitions=30)
df['timeId'] = ((df['time'] - df['time'].min()).apply(lambda x: x.total_seconds()*f, meta=('time', 'float64'))).astype(np.int32)
df = client.persist(df)

# %%
link_count = df.groupby(['src', 'dst']).size().compute().sort_values(ascending=False)
top_links = link_count.iloc[:E]
# Out:
# distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)

# %%
ip_pairs = dict.fromkeys(top_links.index)
series_ip_id = pd.Series(sum(list(ip_pairs.keys()), tuple())).sort_values().drop_duplicates().reset_index(drop=True)
ip_id_map = {ip_: id_ for ip_, id_ in zip(series_ip_id.values, series_ip_id.index)}

# %%
filt_df = df[df.apply(lambda x: (x['src'], x['dst']) in ip_pairs, axis=1, meta=('pandas.Series', 'bool'))].drop(columns='time').groupby(['src', 'dst', 'timeId']).sum().reset_index() # .compute()
filt_df['src'] = filt_df['src'].apply(lambda x: ip_id_map[x], meta=('string', 'int32'))
filt_df['dst'] = filt_df['dst'].apply(lambda x: ip_id_map[x], meta=('string', 'int32')) 
filt_df = filt_df.compute()
filt_df
# Out:
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# distributed.worker - WARNING - gc.collect() took 2.984s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.49 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.76 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.77 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.79 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.80 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.84 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.87 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.88 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.89 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.90 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.90 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.91 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.91 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.91 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.92 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.92 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.93 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.93 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.93 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.93 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.94 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.94 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.95 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.95 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.96 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.96 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.97 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.97 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.89 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.89 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.90 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.90 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.90 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.91 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.92 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.79 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.79 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.79 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.80 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.85 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.87 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.88 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.88 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.88 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.88 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.88 GiB -- Worker memory limit: 15.37 GiB
# distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.67 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.80 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.79 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.81 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.81 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.85 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.88 GiB -- Worker memory limit: 15.37 GiB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.83 GiB -- Worker memory limit: 15.37 GiB
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
#          src  dst  timeId   len
# 0          0  160      82    60
# 1          0  160      83   621
# 2          0  160      84   386
# 3          0  160      85   304
# 4          0  160      87   520
# ...      ...  ...     ...   ...
# 4140740  590  186   22491  1080
# 4140741  590  186   22492  1080
# 4140742  590  186   22493  2160
# 4140743  590  186   22494  1080
# 4140744  590  186   22495  1620
#
# [4140745 rows x 4 columns]

# %%
filt_df
# Out:
#          src  dst  timeId   len
# 0          0  160      82    60
# 1          0  160      83   621
# 2          0  160      84   386
# 3          0  160      85   304
# 4          0  160      87   520
# ...      ...  ...     ...   ...
# 4140740  590  186   22491  1080
# 4140741  590  186   22492  1080
# 4140742  590  186   22493  2160
# 4140743  590  186   22494  1080
# 4140744  590  186   22495  1620
#
# [4140745 rows x 4 columns]

# %%
filt_df.to_csv('temporal_traffic_data.csv', index=False)

# %%
import pickle

# Store data (serialize)
with open('ip_pairs.pickle', 'wb') as file:
    pickle.dump(ip_pairs, file, protocol=pickle.HIGHEST_PROTOCOL)

with open('ip_id_map.pickle', 'wb') as file:
    pickle.dump(ip_id_map, file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
#
#  ('112.146.84.38', '203.208.249.144'): None,
#  ('103.41.180.31', '150.142.249.138'): None,
#  ('203.208.249.144', '58.23.180.88'): None,
#  ('203.208.249.144', '36.198.95.202'): None,
#  ('203.208.247.215', '121.70.76.28'): None,
#  ('117.233.96.134', '150.142.153.190'): None,
#  ('213.175.60.191', '203.208.250.174'): None,
#  ('203.208.249.144', '36.198.95.128'): None,
#  ('23.61.135.116', '163.93.238.225'): None,
#  ('203.208.249.144', '112.146.84.31'): None,
#  ('36.198.95.169', '203.208.249.144'): None,
#  ('203.208.249.144', '112.146.84.64'): None,
#  ('183.168.110.193', '150.142.249.138'): None,
#  ('203.208.249.144', '112.146.84.90'): None,
#  ('23.179.27.232', '163.93.239.37'): None,
#  ('8.33.5.30', '163.93.239.119'): None,
#  ('104.238.162.217', '163.93.246.36'): None,
#  ('203.208.249.144', '58.23.180.223'): None,
#  ('203.208.249.144', '112.146.84.39'): None,
#  ('203.208.249.144', '36.198.94.251'): None,
#  ('126.147.116.212', '203.208.247.215'): None,
#  ('163.93.122.249', '119.64.126.235'): None,
#  ('23.178.247.90', '163.93.238.146'): None,
#  ('112.146.84.3', '203.208.249.144'): None,
#  ('202.211.29.71', '150.142.249.138'): None,
#  ('23.179.27.233', '163.93.239.37'): None,
#  ('36.198.95.170', '203.208.249.144'): None,
#  ('203.208.249.144', '58.23.180.218'): None,
#  ('203.208.249.144', '112.146.84.123'): None,
#  ('121.113.36.172', '150.142.249.138'): None,
#  ('103.195.49.40', '150.142.249.138'): None,
#  ('58.199.209.58', '150.142.249.138'): None}

# %%
N = len(ip_id_map)
T = filt_df['timeId'].max() + 1
F = 2
data_matrix = np.zeros((N, T, F))
data_matrix.shape

# %%
for srcId, dstId, timeId, size in filt_df[['src', 'dst', 'timeId', 'len']].values:
    data_matrix[srcId, timeId, 0] += size
    data_matrix[dstId, timeId, 1] += size

# %%
fig, [ax1, ax2] = plt.subplots(2, figsize=(16, 10), dpi=150)
ax1.plot(np.log2(1 + data_matrix[:15, :, 0].T), ',', alpha=.75)
ax2.plot(np.log2(1 + data_matrix[:15, :, 1].T), ',', alpha=.75)
plt.show()

# %%
fig, [ax1, ax2] = plt.subplots(2, figsize=(16, 10))
ax1.plot(np.log2(1 + data_matrix[:5, :, 0].T), ',', alpha=.25)
ax2.plot(np.log2(1 + data_matrix[:5, :, 1].T), ',', alpha=.25)
plt.show()

fig, [ax1, ax2] = plt.subplots(2, figsize=(16, 10))
ax1.plot(np.log2(1 + data_matrix[-5:, :, 0].T), ',', alpha=.25)
ax2.plot(np.log2(1 + data_matrix[-5:, :, 1].T), ',', alpha=.25)
plt.show()

# %%
plt.scatter(data_matrix.std(axis=1)[:, 0] + 1, data_matrix.std(axis=1)[:, 1] + 1, 
            c=(data_matrix.std(axis=1) > 0).sum(axis=-1) * (data_matrix.std(axis=1)[:, 0] > 0))
plt.yscale('log')
plt.xscale('log')
